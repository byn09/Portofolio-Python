# %% [markdown]
# **Analisis Laju Pertumbuhan Penduduk Pulau Sumatera**
#
# Menganalisis data penduduk pulau sumatera pada Tahun 2018 - Tahun 2022 dan membuat visualisasi data tersebut.
#
# **Data from Badan Pusat Statistik (BPS) Indonesia**

# %% [markdown]
# # **Import Data**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
from google.colab import files
files.upload

# %%
file_path = "/content/Data Penduduk Menurut Provinsi, 2018.csv"
existing_df = pd.read_csv(file_path)
existing_df["Tahun"] = 2018
existing_df.to_csv("/content/Data Penduduk 2018.csv", index=False)

file_path = "/content/Data Penduduk Menurut Provinsi, 2019.csv"
existing_df = pd.read_csv(file_path)
existing_df["Tahun"] = 2019
existing_df.to_csv("/content/Data Penduduk 2019.csv", index=False)

file_path = "/content/Data Penduduk Menurut Provinsi, 2020.csv"
existing_df = pd.read_csv(file_path)
existing_df["Tahun"] = 2020
existing_df.to_csv("/content/Data Penduduk 2020.csv", index=False)

file_path = "/content/Data Penduduk Menurut Provinsi, 2021.csv"
existing_df = pd.read_csv(file_path)
existing_df["Tahun"] = 2021
existing_df.to_csv("/content/Data Penduduk 2021.csv", index=False)

file_path = "/content/Data Penduduk Menurut Provinsi, 2022.csv"
existing_df = pd.read_csv(file_path)
existing_df["Tahun"] = 2022
existing_df.to_csv("/content/Data Penduduk 2022.csv", index=False)

# %%
file_paths = ["/content/Data Penduduk 2018.csv", "/content/Data Penduduk 2019.csv",
              "/content/Data Penduduk 2020.csv", "/content/Data Penduduk 2021.csv",
              "/content/Data Penduduk 2022.csv"]
dfs = [pd.read_csv(file_path) for file_path in file_paths]
merged_df = pd.concat(dfs, ignore_index=True)
merged_df.to_csv("Data Penduduk 2018-2022", index=False)

# %%
df = pd.read_csv('/content/Data Penduduk 2018-2022')
df.head()
# Out:
#          Provinsi  Jumlah Penduduk  Laju Pertumbuhan Penduduk per Tahun  \
# 0            Aceh           5281.3                                 1.96
# 1  Sumatera Utara          14415.4                                 1.27
# 2  Sumatera Barat           5382.1                                 1.27
# 3            Riau           6814.9                                 2.54
# 4           Jambi           3570.3                                 1.75
#
#    Persentase Penduduk  Kepadatan Penduduk per km persegi  \
# 0                 1.99                               91.0
# 1                 5.44                              198.0
# 2                 2.03                              128.0
# 3                 2.57                               78.0
# 4                 1.35                               71.0
#
#    Rasio Jenis Kelamin Penduduk  Tahun
# 0                          99.8   2018
# 1                          99.6   2018
# 2                          99.3   2018
# 3                         105.3   2018
# 4                         104.1   2018

# %%
df = pd.read_csv("/content/Data Penduduk 2018-2022")
Sumatera_provinces = ['Aceh', 'Sumatera Utara', 'Sumatera Barat',
                      'Riau', 'Jambi', 'Bengkulu', 'Kepulauan Riau', 'Sumatera Selatan', 'Lampung']
df_Pulau_Sumatera = df[df['Provinsi'].isin(Sumatera_provinces)]
df_Pulau_Sumatera.to_csv("Data_penduduk_pulau_sumatera.csv", index=False)

# %%
df = pd.read_csv('/content/Data_penduduk_pulau_sumatera.csv')
df.head()
# Out:
#          Provinsi  Jumlah Penduduk  Laju Pertumbuhan Penduduk per Tahun  \
# 0            Aceh           5281.3                                 1.96
# 1  Sumatera Utara          14415.4                                 1.27
# 2  Sumatera Barat           5382.1                                 1.27
# 3            Riau           6814.9                                 2.54
# 4           Jambi           3570.3                                 1.75
#
#    Persentase Penduduk  Kepadatan Penduduk per km persegi  \
# 0                 1.99                               91.0
# 1                 5.44                              198.0
# 2                 2.03                              128.0
# 3                 2.57                               78.0
# 4                 1.35                               71.0
#
#    Rasio Jenis Kelamin Penduduk  Tahun
# 0                          99.8   2018
# 1                          99.6   2018
# 2                          99.3   2018
# 3                         105.3   2018
# 4                         104.1   2018

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 7 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Provinsi                             45 non-null     object
#  1   Jumlah Penduduk                      45 non-null     float64
#  2   Laju Pertumbuhan Penduduk per Tahun  45 non-null     float64
#  3   Persentase Penduduk                  45 non-null     float64
#  4   Kepadatan Penduduk per km persegi    45 non-null     float64
#  5   Rasio Jenis Kelamin Penduduk         45 non-null     float64
#  6   Tahun                                45 non-null     int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 2.6+ KB

# %%
print(df.isnull().sum())
# Out:
# Provinsi                               0
# Jumlah Penduduk                        0
# Laju Pertumbuhan Penduduk per Tahun    0
# Persentase Penduduk                    0
# Kepadatan Penduduk per km persegi      0
# Rasio Jenis Kelamin Penduduk           0
# Tahun                                  0
# dtype: int64

# %%
df.nunique()
# Out:
# Provinsi                                9
# Jumlah Penduduk                        45
# Laju Pertumbuhan Penduduk per Tahun    38
# Persentase Penduduk                    29
# Kepadatan Penduduk per km persegi      34
# Rasio Jenis Kelamin Penduduk           25
# Tahun                                   5
# dtype: int64

# %% [markdown]
# # **EDA**

# %%
df.corr()
# Out:
# <ipython-input-11-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                      Jumlah Penduduk  \
# Jumlah Penduduk                             1.000000
# Laju Pertumbuhan Penduduk per Tahun        -0.457419
# Persentase Penduduk                         0.999646
# Kepadatan Penduduk per km persegi           0.249327
# Rasio Jenis Kelamin Penduduk               -0.371951
# Tahun                                       0.020840
#
#                                      Laju Pertumbuhan Penduduk per Tahun  \
# Jumlah Penduduk                                                -0.457419
# Laju Pertumbuhan Penduduk per Tahun                             1.000000
# Persentase Penduduk                                            -0.454323
# Kepadatan Penduduk per km persegi                               0.213800
# Rasio Jenis Kelamin Penduduk                                    0.282930
# Tahun                                                          -0.140150
#
#                                      Persentase Penduduk  \
# Jumlah Penduduk                                 0.999646
# Laju Pertumbuhan Penduduk per Tahun            -0.454323
# Persentase Penduduk                             1.000000
# Kepadatan Penduduk per km persegi               0.248369
# Rasio Jenis Kelamin Penduduk                   -0.375148
# Tahun                                          -0.001805
#
#                                      Kepadatan Penduduk per km persegi  \
# Jumlah Penduduk                                               0.249327
# Laju Pertumbuhan Penduduk per Tahun                           0.213800
# Persentase Penduduk                                           0.248369
# Kepadatan Penduduk per km persegi                             1.000000
# Rasio Jenis Kelamin Penduduk                                  0.035756
# Tahun                                                         0.032250
#
#                                      Rasio Jenis Kelamin Penduduk     Tahun
# Jumlah Penduduk                                         -0.371951  0.020840
# Laju Pertumbuhan Penduduk per Tahun                      0.282930 -0.140150
# Persentase Penduduk                                     -0.375148 -0.001805
# Kepadatan Penduduk per km persegi                        0.035756  0.032250
# Rasio Jenis Kelamin Penduduk                             1.000000  0.123508
# Tahun                                                    0.123508  1.000000

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(8, 5))
sns.heatmap(df.corr(),
            cmap = ['#4CAF50','#98FB98', '#7CFC00'], annot=True)
plt.title("Data Correlation", weight="bold", fontsize=35, pad=30)
plt.xticks(weight="bold", fontsize=15)
plt.yticks(weight="bold", fontsize=15);
# Out:
# <ipython-input-12-5ceddf6aaad3>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),

# %% [markdown]
# * Jumlah penduduk memiliki hubungan yang cukup kuat dengan Kepadatan Penduduk per km persegi.
# * Jumlah penduduk memiliki hubungan yang kuat dengan persentase penduduk.
# * Hubungan antara tahun dan jumlah penduduk sangat lemah, tetapi ada kecenderungan bahwa seiring berjalannya waktu (tahun meningkat), jumlah penduduk juga sedikit meningkat.
# * Ada kecenderungan untuk laju pertumbuhan menurun sedikit seiring berjalannya waktu, tetapi hubungannya tidak sangat kuat.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Laju Pertumbuhan Penduduk per Tahun', y='Kepadatan Penduduk per km persegi', data=df, hue='Provinsi', palette='bright')
plt.title('Hubungan Laju Pertumbuhan dan Kepadatan Penduduk')
plt.xlabel('Laju Pertumbuhan Penduduk per Tahun')
plt.ylabel('Kepadatan Penduduk per km persegi')
plt.show()

# %% [markdown]
# *   Rata-rata Provinsi yang memiliki kepadatan penduduk paling rendah, laju pertumbuhan penduduknya juga rendah.
# *   Kepulauan Riau dan Riau memiliki laju pertumbuhan penduduk yang tinggi
# *   Sumatera barat memiliki kepadatan penduduk yang sedang, namun laju pertumbuhan penduduknya rendah.
# *   Lampung memiliki kepadatan penduduk yang tinggi, namun laju pertumbuhan penduduknya rendah.

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize = (10,10))
plt.subplots_adjust(hspace=0.8)

plt.subplot(2, 2, 1)
sns.lineplot(x='Tahun', y='Laju Pertumbuhan Penduduk per Tahun', hue='Provinsi', data=df, palette='bright')
plt.title('Time Series Pertumbuhan Penduduk per Tahun')
plt.xlabel('Tahun')
plt.ylabel('Laju Pertumbuhan Penduduk per Tahun')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.subplot(2, 1, 2)
sns.lineplot(x='Tahun', y='Laju Pertumbuhan Penduduk per Tahun', data=df)
plt.title('Time Series Pertumbuhan Penduduk per Tahun')
plt.xlabel('Tahun')
plt.ylabel('Laju Pertumbuhan Penduduk per Tahun')
plt.xticks(df['Tahun'])
plt.show()
# Out:
# <ipython-input-14-72a2d2ca6b15>:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2, 2, 1)

# %%
df['Rolling_Mean'] = df['Jumlah Penduduk'].rolling(window=12).mean()

plt.figure(figsize=(10, 6))
plt.plot(df['Tahun'], df['Jumlah Penduduk'], label='Jumlah Penduduk')
plt.plot(df['Tahun'], df['Rolling_Mean'], label='Rolling Mean', linestyle='--', color='red')
plt.title('Rolling Mean Plot')
plt.xlabel('Tahun')
plt.ylabel('Jumlah Penduduk')
plt.xticks(df['Tahun'])
plt.legend()
plt.show()

# %% [markdown]
# * Pada Tahun 2020 rata-rata laju pertumbuhan penduduk mengalami penurunan drastis.
# * Pada Tahun 2021 rata-rata laju pertumbuhan penduduk mengalami kenaikan.
# * Pada Tahun 2022 laju pertumbuhan penduduk mengalami penurunan namun tidak turun drastis.
# * Rata-rata laju pertumbuhan penduduk dari 2018 ke 2022 mengalami penurunan.
# * Jumlah penduduk dari tahun 2018 ke tahun 2022 mengalami peningkatan.

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x='Provinsi', y='Laju Pertumbuhan Penduduk per Tahun', data=df)
plt.title('Distribusi Laju Pertumbuhan Penduduk per Tahun antar Provinsi')
plt.xlabel('Provinsi')
plt.ylabel('Laju Pertumbuhan Penduduk per Tahun')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Provinsi', y='Laju Pertumbuhan Penduduk per Tahun', data=df, ci=None, palette='viridis')
plt.title('Total Pertumbuhan Penduduk per Provinsi')
plt.xlabel('Provinsi')
plt.ylabel('Total Pertumbuhan Penduduk per Tahun')
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# <ipython-input-17-b3f8b1c8e626>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Provinsi', y='Laju Pertumbuhan Penduduk per Tahun', data=df, ci=None, palette='viridis')
# <ipython-input-17-b3f8b1c8e626>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Provinsi', y='Laju Pertumbuhan Penduduk per Tahun', data=df, ci=None, palette='viridis')

# %% [markdown]
# *   Provinsi dengan Laju pertumbuhan paling tinggi adalah Kepulauan Riau
# *   Provinsi dengan Laju pertumbuhan paling rendah adalah Sumatera Barat

# %% [markdown]
# # **KESIMPULAN**
#
# **Rata-rata laju pertumbuhan penduduk Pulau Sumatera dari 2018 ke 2022 mengalami penurunan. Maka dapat disimpulkan perkiraan laju pertumbuhan penduduk pada tahun berikutnya mengalami penurunan juga. Namun perlu ditelusuri kembali beberapa faktor lainnya.**
